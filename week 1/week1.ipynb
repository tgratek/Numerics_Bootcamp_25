# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define functions

# %%
# Definición de las funciones c(x) y f(x)
def c(x):
    return 10 * np.sin(2 * np.pi * x) + 15

def f(x):    
    return np.exp(-x) * (4 * np.pi * np.cos(2 * np.pi * x) + (4 * np.pi**2 + 14) * np.sin(2 * np.pi * x) + 5 - 5 * np.cos(4 * np.pi * x))

# Solución exacta para una comparación (si es conocida, en este caso supondremos una solución)
def exact_solution(x):
    return np.exp(-x) * np.sin(2 * np.pi * x)

# %% [markdown]
# # FDM implementation 1 (less efficient)

# %%
# # Método de diferencias finitas
# def finite_difference(n):
#     h = 1 / (n + 1)
#     x = np.linspace(0, 1, n + 2)
#     A = np.zeros((n, n))
#     b = np.zeros(n)
    
#     # Construcción de la matriz A y el vector b
#     for i in range(1, n+1):
#         xi = i * h
#         A[i-1, i-1] = 2 / h**2 + c(xi)
#         if i > 1:
#             A[i-1, i-2] = -1 / h**2
#         if i < n:
#             A[i-1, i] = -1 / h**2
#         b[i-1] = f(xi)
    
#     # Resolviendo el sistema A*u = b
#     u = np.linalg.solve(A, b)
    
#     # Agregar las condiciones de frontera homogéneas
#     u = np.concatenate(([0], u, [0]))
#     x = np.linspace(0, 1, n + 2)
#     return x, u

# %% [markdown]
# # FDM implementation 2

# %%
# Método de diferencias finitas
def finite_difference(n):
    h = 1 / (n + 1)
    x = np.linspace(0, 1, n + 2)
    b = np.zeros(n)
    c_ = np.zeros(n)
    
    # Construcción de la matriz A y el vector b
    for i in range(1, n+1):
        xi = i * h
        c_[i-1] = c(xi)
        b[i-1] = f(xi)
    
    A = (2*np.diag(np.ones(n),k=0) - 1*np.diag(np.ones(n-1),k=1) - 1*np.diag(np.ones(n-1), k=-1)) / (h**2) + np.diag(c_)
    
    # Resolviendo el sistema A*u = b
    u = np.linalg.solve(A, b)
    
    # Agregar las condiciones de frontera homogéneas
    u = np.concatenate(([0], u, [0]))
    x = np.linspace(0, 1, n + 2)
    return x, u

# %% [markdown]
# # Create plotters

# %%
# Graph sol
def plot_solution(n):
    x_exact = np.linspace(0, 1, 1000)
    u_exact = exact_solution(x_exact)
    
    x_fd, u_fd = finite_difference(n)
    
    plt.figure(figsize=(10, 6))
    plt.plot(x_fd, u_fd, 'o-', label='Solution by FDM (n={})'.format(n), c='darkorange')
    plt.plot(x_exact, u_exact, label='Exact solution')
    plt.xlabel('x')
    plt.ylabel('u(x)')
    plt.title('Comparison between exact solution and FDM approximation')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Convergence analysis
def convergence_analysis():
    ns = [5, 10, 20, 40, 80, 160, 320, 640, 1280]
    errors = []

    for n in ns:
        x_fd, u_fd = finite_difference(n)
        x_exact = np.linspace(0, 1, n + 2)
        u_exact = exact_solution(x_exact)
        error = np.linalg.norm(u_fd - u_exact, ord=np.inf)
        errors.append(error)

    slope, _ = np.polyfit(np.log(ns), np.log(errors), 1)
    
    #plt.plot(np.arange(len(ns)), np.log(errors))
    plt.figure(figsize=(10, 6))
    plt.loglog(ns, errors, 'o-', label=f'Slope = {slope}')
    plt.xlabel('Number of intervals (n)')
    plt.ylabel('Error')
    plt.title('Error convergence')
    plt.legend()
    plt.grid(True, which='both', linestyle='--')
    plt.show()

# %% [markdown]
# # Plot results

# %%
plot_solution(40)

# %%
convergence_analysis()
